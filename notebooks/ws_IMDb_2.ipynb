# %% [markdown]
# ## Fazendo Web Scraping do Top 250 filmes do IMDb

# %%
import time, random
from bs4 import BeautifulSoup
import requests
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager # Ajuda a gerenciar o chromedriver

# Configura o driver do Selenium para controlar o Chrome
# O ChromeDriverManager baixa e gerencia o driver automaticamente
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

# URL do nosso alvo
url = 'https://www.imdb.com/chart/top/'

# Selenium abre a página no navegador
driver.get(url)

# Espera inicial para a página carregar
time.sleep(3)

# Rola a página para baixo para carregar todos os filmes dinamicamente
while True:
    # Conta quantos filmes estão carregados na página
    filmes_carregados = len(driver.find_elements(By.CSS_SELECTOR, 'ul.ipc-metadata-list li'))

    if filmes_carregados >= 250:
        print('Todos os 250 filmes foram carregados.')
        break

    # Executa um script para rolar até o final da página
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    # Espera um pouco para o novo conteúdo carregar
    time.sleep(2)

# Pega o HTML completo da página depois que tudo foi carregado
html_completo = driver.page_source

# Fecha o navegador controlado pelo Selenium
driver.quit()
# Out:
# Todos os 250 filmes foram carregados.

# %%
# Definindo 'headers' para simular um navegador
# Alguns sites bloqueiam requisições que não parecem vir de um navegador real.
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0 Safari/537.36'
}

# Criando uma sessão persistente
# Reaproveita cookies/conexões e aplica headers em todas as requisições
session = requests.Session()
session.headers.update(headers)

# Função auxiliar para extrair o texto de um elemento do BeautifulSoup
def get_text(el):
    return el.get_text(strip=True) if el else None

# Função para fazer a requisição HTTP com várias tentativas (retries)
def fetch(url, retries=3, backoff=2):
    for i in range(retries):
        try:
            r = session.get(url, timeout=20) # Timeout evita travar se o servidor não responder
            if r.status_code == 200: # Se resposta OK, retorna imediatamente
                return r
            print(f'Tentativa {i+1} falhou para {url} com status {r.status_code}')
        except requests.exceptions.RequestException as e:
            print(f'Tentativa {i+1} falhou para {url} com erro: {e}')
        time.sleep(backoff ** i) # Espera antes da próxima tentativa
    raise RuntimeError(f'Falha ao baixar: {url}') # Se todas as tentativas falharem, lança erro

# Analisando (parsing) o conteúdo HTML COMPLETO com o BeautifulSoup
# A única mudança aqui é usar 'html_completo' vindo do Selenium
soup = BeautifulSoup(html_completo, 'html.parser')

# Encontrando a lista de filmes
filmes_data = []
# A investigação mostrou que cada filme está em uma tag <li> dentro de uma <ul> com a classe 'ipc-metadata-list'
lista_filmes = soup.find('ul', class_='ipc-metadata-list')

print('\nIniciando a extração dos dados de cada filme...')
for i, filme_li in enumerate(lista_filmes.find_all('li')):
    try:
        # Dados básicos do filme na primeira página
        # Extraindo Título, Ano e Nota
        titulo_tag = filme_li.find('h3', class_='ipc-title__text')
        if not titulo_tag:
            continue
        titulo = titulo_tag.text.split('. ', 1)[1]
        print(f'Extraindo dados do filme {i+1}/250: {titulo}')

        metadata = filme_li.find_all('span', class_='cli-title-metadata-item')
        ano = metadata[0].text if metadata else None

        nota_tag = filme_li.find('span', class_='ipc-rating-star')
        nota = get_text(nota_tag).split('(')[0].strip() if nota_tag else None

        # Extraindo o LINK para a página do filme específico
        link_relativo = filme_li.find('a')['href']
        link_completo = 'https://www.imdb.com' + link_relativo

        # Acessando a página individual do filme para mais detalhes
        time.sleep(random.uniform(1.0, 2.0))  # Pausa para respeitar o site
        response_filme = fetch(link_completo)
        soup_filme = BeautifulSoup(response_filme.content, 'html.parser')

        # Sinopse (fallbacks pois o data-testid muda às vezes)
        sinopse = None
        for sel in [
                '[data-testid="plot-xl"]',
                '[data-testid="plot-l"]',
                'span[data-testid="plot-xl"]',
                'span[data-testid="plot"]',
                'div[data-testid="storyline-plot-summary"] > div > div'
            ]:
            el = soup_filme.select_one(sel)
            if el:
                sinopse = get_text(el)
                break

        # Elenco principal
        elenco_tags = soup_filme.select("a[data-testid='title-cast-item__actor']")
        elenco = [get_text(a) for a in elenco_tags][:3]

        # Diretor
        diretor = None
        creditos_tags = soup_filme.find_all('ul', {'role': 'presentation', 'class': 'ipc-metadata-list'})
        if creditos_tags:
            a0 = creditos_tags[0].find('a')
            diretor = get_text(a0)

        filmes_data.append({
            'Título': titulo,
            'Ano': ano,
            'Nota': nota,
            'Sinopse': sinopse,
            'Diretor': diretor,
            'Elenco Principal': ', '.join(elenco) # Juntando o elenco em uma string
        })

    except Exception as e:
        print(f"Falha ao extrair dados de '{titulo if 'titulo' in locals() else 'Desconhecido'}': {e}")

print('\nColeta finalizada!')
print(f'Total de filmes extraídos: {len(filmes_data)}')

for filme in filmes_data[:5]:
    print(filme)
# Out:
# Iniciando a extração dos dados de cada filme...
# Extraindo dados do filme 1/250: Um Sonho de Liberdade
# Extraindo dados do filme 2/250: O Poderoso Chefão
# Extraindo dados do filme 3/250: Batman: O Cavaleiro das Trevas
# Extraindo dados do filme 4/250: O Poderoso Chefão: Parte II
# Extraindo dados do filme 5/250: 12 Homens e uma Sentença
# Extraindo dados do filme 6/250: O Senhor dos Anéis: O Retorno do Rei
# Extraindo dados do filme 7/250: A Lista de Schindler
# Extraindo dados do filme 8/250: O Senhor dos Anéis: A Sociedade do Anel
# Extraindo dados do filme 9/250: Pulp Fiction: Tempo de Violência
# Extraindo dados do filme 10/250: Três Homens em Conflito
# Extraindo dados do filme 11/250: Forrest Gump: O Contador de Histórias
# Extraindo dados do filme 12/250: O Senhor dos Anéis: As Duas Torres
# Extraindo dados do filme 13/250: Clube da Luta
# Extraindo dados do filme 14/250: A Origem
# Extraindo dados do filme 15/250: Star Wars: Episódio V - O Império Contra-Ataca
# Extraindo dados do filme 16/250: Matrix
# Extraindo dados do filme 17/250: Os Bons Companheiros
# Extraindo dados do filme 18/250: Interestelar
# Extraindo dados do filme 19/250: Um Estranho no Ninho
# Extraindo dados do filme 20/250: Seven - Os Sete Crimes Capitais
# Extraindo dados do filme 21/250: A Felicidade Não se Compra
# Extraindo dados do filme 22/250: O Silêncio dos Inocentes
# Extraindo dados do filme 23/250: Os Sete Samurais
# Extraindo dados do filme 24/250: O Resgate do Soldado Ryan
# Extraindo dados do filme 25/250: À Espera de um Milagre
# Extraindo dados do filme 26/250: Cidade de Deus
# Extraindo dados do filme 27/250: A Vida é Bela
# Extraindo dados do filme 28/250: O Exterminador do Futuro 2: O Julgamento Final
# Extraindo dados do filme 29/250: Star Wars: Episódio IV - Uma Nova Esperança
# Extraindo dados do filme 30/250: De Volta para o Futuro
# Extraindo dados do filme 31/250: A Viagem de Chihiro
# Extraindo dados do filme 32/250: O Pianista
# Extraindo dados do filme 33/250: Gladiador
# Extraindo dados do filme 34/250: Parasita
# Extraindo dados do filme 35/250: Psicose
# Extraindo dados do filme 36/250: O Rei Leão
# Extraindo dados do filme 37/250: Túmulo dos Vagalumes
# Extraindo dados do filme 38/250: Os Infiltrados
# Extraindo dados do filme 39/250: Whiplash: Em Busca da Perfeição
# Extraindo dados do filme 40/250: Harakiri
# Extraindo dados do filme 41/250: O Grande Truque
# Extraindo dados do filme 42/250: A Outra História Americana
# Extraindo dados do filme 43/250: O Profissional
# Extraindo dados do filme 44/250: Homem-Aranha: Através do Aranhaverso
# Extraindo dados do filme 45/250: Casablanca
# Extraindo dados do filme 46/250: Cinema Paradiso
# Extraindo dados do filme 47/250: Intocáveis
# Extraindo dados do filme 48/250: Os Suspeitos
# Extraindo dados do filme 49/250: Alien - O 8º Passageiro
# Extraindo dados do filme 50/250: Tempos Modernos
# Extraindo dados do filme 51/250: Janela Indiscreta
# Extraindo dados do filme 52/250: Django Livre
# Extraindo dados do filme 53/250: Era uma Vez no Oeste
# Extraindo dados do filme 54/250: Luzes da Cidade
# Extraindo dados do filme 55/250: Apocalypse Now
# Extraindo dados do filme 56/250: WALL·E
# Extraindo dados do filme 57/250: Amnésia
# Extraindo dados do filme 58/250: Duna: Parte 2
# Extraindo dados do filme 59/250: Os Caçadores da Arca Perdida
# Extraindo dados do filme 60/250: Vingadores: Guerra Infinita
# Extraindo dados do filme 61/250: A Vida dos Outros
# Extraindo dados do filme 62/250: Crepúsculo dos Deuses
# Extraindo dados do filme 63/250: Homem-Aranha: No Aranhaverso
# Extraindo dados do filme 64/250: Testemunha de Acusação
# Extraindo dados do filme 65/250: Glória Feita de Sangue
# Extraindo dados do filme 66/250: O Iluminado
# Extraindo dados do filme 67/250: O Grande Ditador
# Extraindo dados do filme 68/250: Bastardos Inglórios
# Extraindo dados do filme 69/250: Repetente
# Extraindo dados do filme 70/250: Aliens: O Resgate
# Extraindo dados do filme 71/250: Batman: O Cavaleiro das Trevas Ressurge
# Extraindo dados do filme 72/250: Viva: A Vida é uma Festa
# Extraindo dados do filme 73/250: Amadeus
# Extraindo dados do filme 74/250: Vingadores: Ultimato
# Extraindo dados do filme 75/250: Céu e Inferno
# Extraindo dados do filme 76/250: Gênio Indomável
# Extraindo dados do filme 77/250: Toy Story
# Extraindo dados do filme 78/250: Oldboy
# Extraindo dados do filme 79/250: Dr. Fantástico
# Extraindo dados do filme 80/250: O Barco: Inferno no Mar
# Extraindo dados do filme 81/250: Coração Valente
# Extraindo dados do filme 82/250: Your Name
# Extraindo dados do filme 83/250: Princesa Mononoke
# Extraindo dados do filme 84/250: Beleza Americana
# Extraindo dados do filme 85/250: 3 Idiotas
# Extraindo dados do filme 86/250: Coringa
# Extraindo dados do filme 87/250: Cafarnaum
# Extraindo dados do filme 88/250: Era uma Vez na América
# Extraindo dados do filme 89/250: Cantando na Chuva
# Extraindo dados do filme 90/250: Vá e Veja
# Extraindo dados do filme 91/250: Réquiem para um Sonho
# Extraindo dados do filme 92/250: Star Wars: Episódio VI - O Retorno de Jedi
# Extraindo dados do filme 93/250: Toy Story 3
# Extraindo dados do filme 94/250: A Caça
# Extraindo dados do filme 95/250: Viver
# Extraindo dados do filme 96/250: Brilho Eterno de uma Mente sem Lembranças
# Extraindo dados do filme 97/250: Incêndios
# Extraindo dados do filme 98/250: Se Meu Apartamento Falasse
# Extraindo dados do filme 99/250: Lawrence da Arábia
# Extraindo dados do filme 100/250: 2001: Uma Odisséia no Espaço
# Extraindo dados do filme 101/250: Cães de Aluguel
# Extraindo dados do filme 102/250: Scarface
# Extraindo dados do filme 103/250: Fogo Contra Fogo
# Extraindo dados do filme 104/250: Pacto de Sangue
# Extraindo dados do filme 105/250: Intriga Internacional
# Extraindo dados do filme 106/250: Up: Altas Aventuras
# Extraindo dados do filme 107/250: M, o Vampiro de Dusseldorf
# Extraindo dados do filme 108/250: Cidadão Kane
# Extraindo dados do filme 109/250: Nascido para Matar
# Extraindo dados do filme 110/250: Um Corpo que Cai
# Extraindo dados do filme 111/250: O Fabuloso Destino de Amélie Poulain
# Extraindo dados do filme 112/250: Como Estrelas na Terra
# Extraindo dados do filme 113/250: A Separação
# Extraindo dados do filme 114/250: O Sol é para Todos
# Extraindo dados do filme 115/250: Duro de Matar
# Extraindo dados do filme 116/250: Golpe de Mestre
# Extraindo dados do filme 117/250: Indiana Jones e a Última Cruzada
# Extraindo dados do filme 118/250: Laranja Mecânica
# Extraindo dados do filme 119/250: Metrópolis
# Extraindo dados do filme 120/250: Snatch - Porcos e Diamantes
# Extraindo dados do filme 121/250: 1917
# Extraindo dados do filme 122/250: Oppenheimer
# Extraindo dados do filme 123/250: Los Angeles: Cidade Proibida
# Extraindo dados do filme 124/250: A Queda! As Últimas Horas de Hitler
# Extraindo dados do filme 125/250: Ladrões de Bicicletas
# Extraindo dados do filme 126/250: Dangal
# Extraindo dados do filme 127/250: O Lobo de Wall Street
# Extraindo dados do filme 128/250: Green Book: O Guia
# Extraindo dados do filme 129/250: O Show de Truman: O Show da Vida
# Extraindo dados do filme 130/250: Hamilton
# Extraindo dados do filme 131/250: Taxi Driver: Motorista de Táxi
# Extraindo dados do filme 132/250: Batman Begins
# Extraindo dados do filme 133/250: Hababam Sinifi Sinifta Kaldi
# Extraindo dados do filme 134/250: Por uns Dólares a Mais
# Extraindo dados do filme 135/250: Julgamento em Nuremberg
# Extraindo dados do filme 136/250: Ilha do Medo
# Extraindo dados do filme 137/250: Quanto Mais Quente Melhor
# Extraindo dados do filme 138/250: Jurassic Park: O Parque dos Dinossauros
# Extraindo dados do filme 139/250: O Garoto
# Extraindo dados do filme 140/250: Meu Pai
# Extraindo dados do filme 141/250: Sangue Negro
# Extraindo dados do filme 142/250: A Malvada
# Extraindo dados do filme 143/250: O Sexto Sentido
# Extraindo dados do filme 144/250: Ran
# Extraindo dados do filme 145/250: Cassino
# Extraindo dados do filme 146/250: Top Gun: Maverick
# Extraindo dados do filme 147/250: Onde os Fracos Não Têm Vez
# Extraindo dados do filme 148/250: O Enigma de Outro Mundo
# Extraindo dados do filme 149/250: Os Imperdoáveis
# Extraindo dados do filme 150/250: O Labirinto do Fauno
# Extraindo dados do filme 151/250: Kill Bill: Volume 1
# Extraindo dados do filme 152/250: Uma Mente Brilhante
# Extraindo dados do filme 153/250: Os Suspeitos
# Extraindo dados do filme 154/250: O Tesouro da Sierra Madre
# Extraindo dados do filme 155/250: Procurando Nemo
# Extraindo dados do filme 156/250: O Castelo Animado
# Extraindo dados do filme 157/250: Yojimbo, o Guarda-Costas
# Extraindo dados do filme 158/250: O Melhor da Juventude
# Extraindo dados do filme 159/250: Fugindo do Inferno
# Extraindo dados do filme 160/250: Monty Python em Busca do Cálice Sagrado
# Extraindo dados do filme 161/250: O Homem Elefante
# Extraindo dados do filme 162/250: Klaus
# Extraindo dados do filme 163/250: Disque M para Matar
# Extraindo dados do filme 164/250: ...E o Vento Levou
# Extraindo dados do filme 165/250: O Segredo dos Seus Olhos
# Extraindo dados do filme 166/250: Chinatown
# Extraindo dados do filme 167/250: Jogos, Trapaças e Dois Canos Fumegantes
# Extraindo dados do filme 168/250: V de Vingança
# Extraindo dados do filme 169/250: Rashomon
# Extraindo dados do filme 170/250: Divertida Mente
# Extraindo dados do filme 171/250: Três Anúncios para um Crime
# Extraindo dados do filme 172/250: Prenda-Me se for Capaz
# Extraindo dados do filme 173/250: Trainspotting: Sem Limites
# Extraindo dados do filme 174/250: A Ponte do Rio Kwai
# Extraindo dados do filme 175/250: Touro Indomável
# Extraindo dados do filme 176/250: Harry Potter e as Relíquias da Morte - Parte 2
# Extraindo dados do filme 177/250: Fargo: Uma Comédia de Erros
# Extraindo dados do filme 178/250: Robô Selvagem
# Extraindo dados do filme 179/250: Guerreiro
# Extraindo dados do filme 180/250: Sociedade dos Poetas Mortos
# Extraindo dados do filme 181/250: Menina de Ouro
# Extraindo dados do filme 182/250: Ben-Hur
# Extraindo dados do filme 183/250: Gran Torino
# Extraindo dados do filme 184/250: Mad Max: Estrada da Fúria
# Extraindo dados do filme 185/250: Barry Lyndon
# Extraindo dados do filme 186/250: Meu Amigo Totoro
# Extraindo dados do filme 187/250: Filhos do Paraíso
# Extraindo dados do filme 188/250: Até o Último Homem
# Extraindo dados do filme 189/250: O Grande Hotel Budapeste
# Extraindo dados do filme 190/250: 12 Anos de Escravidão
# Extraindo dados do filme 191/250: Antes do Amanhecer
# Extraindo dados do filme 192/250: Blade Runner: O Caçador de Andróides
# Extraindo dados do filme 193/250: Homem-Aranha: Sem Volta para Casa
# Extraindo dados do filme 194/250: Memórias de um Assassino
# Extraindo dados do filme 195/250: Ratatouille
# Extraindo dados do filme 196/250: Garota Exemplar
# Extraindo dados do filme 197/250: Como Treinar o Seu Dragão
# Extraindo dados do filme 198/250: Monstros S.A.
# Extraindo dados do filme 199/250: Tubarão
# Extraindo dados do filme 200/250: Em Nome do Pai
# Extraindo dados do filme 201/250: Relatos Selvagens
# Extraindo dados do filme 202/250: Em Busca do Ouro
# Extraindo dados do filme 203/250: Ford vs. Ferrari
# Extraindo dados do filme 204/250: Bancando o Águia
# Extraindo dados do filme 205/250: Mary e Max - Uma Amizade Diferente
# Extraindo dados do filme 206/250: O Franco Atirador
# Extraindo dados do filme 207/250: A General
# Extraindo dados do filme 208/250: O Salário do Medo
# Extraindo dados do filme 209/250: Demon Slayer: Kimetsu no Yaiba - Castelo Infinito
# Extraindo dados do filme 210/250: A Mulher Faz o Homem
# Extraindo dados do filme 211/250: Logan
# Extraindo dados do filme 212/250: Sindicato de Ladrões
# Extraindo dados do filme 213/250: Rocky, um Lutador
# Extraindo dados do filme 214/250: Morangos Silvestres
# Extraindo dados do filme 215/250: Era uma Vez em Tóquio
# Extraindo dados do filme 216/250: O 3º Homem
# Extraindo dados do filme 217/250: O Mistério da Lixeira
# Extraindo dados do filme 218/250: Spotlight: Segredos Revelados
# Extraindo dados do filme 219/250: Piratas do Caribe: A Maldição do Pérola Negra
# Extraindo dados do filme 220/250: O Exterminador do Futuro
# Extraindo dados do filme 221/250: O Ódio
# Extraindo dados do filme 222/250: O Grande Lebowski
# Extraindo dados do filme 223/250: Jai Bhim
# Extraindo dados do filme 224/250: O Sétimo Selo
# Extraindo dados do filme 225/250: O Quarto de Jack
# Extraindo dados do filme 226/250: Hotel Ruanda
# Extraindo dados do filme 227/250: Platoon
# Extraindo dados do filme 228/250: Os Melhores Anos de Nossas Vidas
# Extraindo dados do filme 229/250: Antes do Pôr do Sol
# Extraindo dados do filme 230/250: A Noviça Rebelde
# Extraindo dados do filme 231/250: O Exorcista
# Extraindo dados do filme 232/250: Os Incríveis
# Extraindo dados do filme 233/250: Sempre ao Seu Lado
# Extraindo dados do filme 234/250: Rush: No Limite da Emoção
# Extraindo dados do filme 235/250: O Mágico de Oz
# Extraindo dados do filme 236/250: A Voz do Silêncio
# Extraindo dados do filme 237/250: O Martírio de Joana D'Arc
# Extraindo dados do filme 238/250: Conta Comigo
# Extraindo dados do filme 239/250: O Gigante de Ferro
# Extraindo dados do filme 240/250: Meu Pai e Meu Filho
# Extraindo dados do filme 241/250: A Criada
# Extraindo dados do filme 242/250: Rede de Intrigas
# Extraindo dados do filme 243/250: A Batalha de Argel
# Extraindo dados do filme 244/250: As Vinhas da Ira
# Extraindo dados do filme 245/250: Demon Slayer: Mugen Train - O Filme
# Extraindo dados do filme 246/250: Ser ou Não Ser
# Extraindo dados do filme 247/250: Kimetsu no Yaiba: Tsuzumi Yashiki-hen
# Extraindo dados do filme 248/250: Gangues de Wasseypur
# Extraindo dados do filme 249/250: Na Natureza Selvagem
# Extraindo dados do filme 250/250: Histórias Cruzadas
#
# Coleta finalizada!
# Total de filmes extraídos: 250
# {'Título': 'Um Sonho de Liberdade', 'Ano': '1994', 'Nota': '9,3', 'Sinopse': 'Dois homens presos se reúnem ao longo de vários anos, encontrando consolo e eventual redenção através de atos de decência comum.', 'Diretor': 'Frank Darabont', 'Elenco Principal': 'Tim Robbins, Morgan Freeman, Bob Gunton'}
# {'Título': 'O Poderoso Chefão', 'Ano': '1972', 'Nota': '9,2', 'Sinopse': 'O patriarca idoso de uma dinastia do crime organizado transfere o controle de seu império clandestino para seu filho relutante.', 'Diretor': 'Francis Ford Coppola', 'Elenco Principal': 'Marlon Brando, Al Pacino, James Caan'}
# {'Título': 'Batman: O Cavaleiro das Trevas', 'Ano': '2008', 'Nota': '9,1', 'Sinopse': 'Agora com a ajuda do tenente Jim Gordon e do promotor público Harvey Dent, Batman tem tudo para banir o crime de Gotham City de uma vez por todas. Mas em breve, os três serão vítimas do Coringa, que pretende lançar Gotham em uma anarquia.', 'Diretor': 'Christopher Nolan', 'Elenco Principal': 'Christian Bale, Heath Ledger, Aaron Eckhart'}
# {'Título': 'O Poderoso Chefão: Parte II', 'Ano': '1974', 'Nota': '9,0', 'Sinopse': 'O início da vida e da carreira de Vito Corleone na década de 1920 em Nova York, enquanto seu filho, Michael, expande e fortalece seu controle sobre o sindicato do crime.', 'Diretor': 'Francis Ford Coppola', 'Elenco Principal': 'Al Pacino, Robert De Niro, Robert Duvall'}
# {'Título': '12 Homens e uma Sentença', 'Ano': '1957', 'Nota': '9,0', 'Sinopse': 'O julgamento de um assassinato em Nova Iorque é frustrado por um único membro, cujo ceticismo força o júri a considerar cuidadosamente as evidências antes de dar o veredito.', 'Diretor': 'Sidney Lumet', 'Elenco Principal': 'Henry Fonda, Lee J. Cobb, Martin Balsam'}

# %%
df_filmes = pd.DataFrame(filmes_data)

caminho_arquivo = '../data/raw/imdb_top_250.csv'
df_filmes.to_csv(caminho_arquivo, index=False,
                                  sep = ';',
                                  decimal = ',',
                                  encoding = 'latin1'
)

print(f"\nDados salvos com sucesso em: {caminho_arquivo}")

df_filmes.head(10)
# Out:
# Dados salvos com sucesso em: ../data/raw/imdb_top_250.csv
#                                     Título   Ano Nota  \
# 0                    Um Sonho de Liberdade  1994  9,3
# 1                        O Poderoso Chefão  1972  9,2
# 2           Batman: O Cavaleiro das Trevas  2008  9,1
# 3              O Poderoso Chefão: Parte II  1974  9,0
# 4                 12 Homens e uma Sentença  1957  9,0
# 5     O Senhor dos Anéis: O Retorno do Rei  2003  9,0
# 6                     A Lista de Schindler  1993  9,0
# 7  O Senhor dos Anéis: A Sociedade do Anel  2001  8,9
# 8         Pulp Fiction: Tempo de Violência  1994  8,8
# 9                  Três Homens em Conflito  1966  8,8
#
#                                              Sinopse               Diretor  \
# 0  Dois homens presos se reúnem ao longo de vário...        Frank Darabont
# 1  O patriarca idoso de uma dinastia do crime org...  Francis Ford Coppola
# 2  Agora com a ajuda do tenente Jim Gordon e do p...     Christopher Nolan
# 3  O início da vida e da carreira de Vito Corleon...  Francis Ford Coppola
# 4  O julgamento de um assassinato em Nova Iorque ...          Sidney Lumet
# 5  Gandalf e Aragorn lideram o Mundo dos Homens c...         Peter Jackson
# 6  Na Polônia ocupada pelos alemães durante a Seg...      Steven Spielberg
# 7  Um manso hobbit do Condado e oito companheiros...         Peter Jackson
# 8  As vidas de dois assassinos da máfia, um boxea...     Quentin Tarantino
# 9  Um impostor se junta com dois homens para enco...          Sergio Leone
#
#                                 Elenco Principal
# 0        Tim Robbins, Morgan Freeman, Bob Gunton
# 1           Marlon Brando, Al Pacino, James Caan
# 2    Christian Bale, Heath Ledger, Aaron Eckhart
# 3       Al Pacino, Robert De Niro, Robert Duvall
# 4        Henry Fonda, Lee J. Cobb, Martin Balsam
# 5     Elijah Wood, Viggo Mortensen, Ian McKellen
# 6       Liam Neeson, Ralph Fiennes, Ben Kingsley
# 7       Elijah Wood, Ian McKellen, Orlando Bloom
# 8  John Travolta, Uma Thurman, Samuel L. Jackson
# 9     Clint Eastwood, Eli Wallach, Lee Van Cleef
